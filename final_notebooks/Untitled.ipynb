# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
filepath_1 = r"C:\Users\Jason Ha\Documents\University\4th Year\Thesis Project (Repo)\Jupyter Notebooks\Active Projects\mass_data\01-02-0001_PSG\1.csv"
filepath_2 = r"C:\Users\Jason Ha\Documents\University\4th Year\Thesis Project (Repo)\Jupyter Notebooks\Active Projects\mass_data\01-02-0012_PSG\12.csv"

df1 = pd.read_csv(filepath_1)
df2 = pd.read_csv(filepath_2)

# %%
df1_sdt = df1[['sdt_ratio', 'label']]
df2_sdt = df2[['sdt_ratio', 'label']]

# %%
fig = plt.figure(figsize=(10,8))
plt.boxplot([df1_sdt[df1_sdt['label'] == 1]['sdt_ratio'], df1_sdt[df1_sdt['label'] == 0]['sdt_ratio']], showfliers=False)
plt.title("SDT Ratio Distribution For Spindle and Non-Spindles - MASS Patient #1", fontweight='bold', fontsize=14)
plt.savefig("sdt_flawed_1.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
plt.boxplot([df2_sdt[df2_sdt['label'] == 1]['sdt_ratio'], df2_sdt[df2_sdt['label'] == 0]['sdt_ratio']], showfliers=False)
plt.show()
